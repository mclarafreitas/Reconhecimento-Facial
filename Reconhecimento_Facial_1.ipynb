# %% [markdown]
# <a href="https://colab.research.google.com/github/mclarafreitas/Reconhecimento-Facial/blob/main/Reconhecimento_Facial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - ## Projeto final de Tópicos Avançados em Informática I
#
# Reconhecimento Facial
#
# Alunos:
# *   Maria Clara Moura de Freitas
# *   Yuri Ferreira Borges

# %% [markdown]
# Fonte:
#
# https://scikit-learn.org/stable/auto_examples/applications/plot_face_recognition.html#sphx-glr-auto-examples-applications-plot-face-recognition-py

# %%
#Baixando o OpenCV
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# - # Importação das bibliotecas

# %%
import cv2
from google.colab.patches import cv2_imshow
from google.colab.patches import cv2

from time import time #Será usado para calcular o tempo de execução.
import matplotlib.pyplot as plt #Será usado para plotar os gráficos.
from sklearn.model_selection import train_test_split #Será usado para para dividir o conjunto de dados em treinamento e teste.
from sklearn.model_selection import RandomizedSearchCV #Será usada para realizar uma busca aleatória nos hiperparâmetros de um modelo de classificação.
from sklearn.datasets import fetch_lfw_people
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.utils.fixes import loguniform

# %%
video = cv2.VideoCapture()
ip = "https://192.168.1.88:8080/video"
video.open(ip)

# Lê apenas o primeiro frame
check, img = video.read()

# Verifica se a leitura do quadro foi bem-sucedida
if check:
    # Converter a imagem de BGR para RGB
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Exibir a imagem usando o matplotlib
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.show()

video.release()

# %% [markdown]
# - # Download, carregamento de dados e preparação dos dados

# %%
lfw_people = fetch_lfw_people(min_faces_per_person=70, resize=0.4)

# introspect the images arrays to find the shapes (for plotting)
n_samples, h, w = lfw_people.images.shape

# for machine learning we use the 2 data directly (as relative pixel
# positions info is ignored by this model)
X = lfw_people.data
n_features = X.shape[1]

# the label to predict is the id of the person
y = lfw_people.target
target_names = lfw_people.target_names
n_classes = target_names.shape[0]

print("Total dataset size:")
print("n_samples: %d" % n_samples)
print("n_features: %d" % n_features)
print("n_classes: %d" % n_classes)
# Out:
# Total dataset size:
# n_samples: 1288
# n_features: 1850
# n_classes: 7

# %% [markdown]
# - # Divisão de dados e conjunto de treinamento

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# - # Análise dos componentes e projeção dos dados PCA

# %%
n_components = 150

print(
    "Extracting the top %d eigenfaces from %d faces" % (n_components, X_train.shape[0])
)
t0 = time()
pca = PCA(n_components=n_components, svd_solver="randomized", whiten=True).fit(X_train)
print("done in %0.3fs" % (time() - t0))

eigenfaces = pca.components_.reshape((n_components, h, w))

print("Projecting the input data on the eigenfaces orthonormal basis")
t0 = time()
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)
print("done in %0.3fs" % (time() - t0))
# Out:
# Extracting the top 150 eigenfaces from 966 faces
# done in 0.581s
# Projecting the input data on the eigenfaces orthonormal basis
# done in 0.064s

# %% [markdown]
# - # Treinamento do modelo SVM

# %%
print("Fitting the classifier to the training set")
t0 = time()
param_grid = {
    "C": loguniform(1e3, 1e5),
    "gamma": loguniform(1e-4, 1e-1),
}
clf = RandomizedSearchCV(
    SVC(kernel="rbf", class_weight="balanced"), param_grid, n_iter=10
)
clf = clf.fit(X_train_pca, y_train)
print("done in %0.3fs" % (time() - t0))
print("Best estimator found by grid search:")
print(clf.best_estimator_)
# Out:
# Fitting the classifier to the training set
# done in 6.816s
# Best estimator found by grid search:
# SVC(C=61969.73466440052, class_weight='balanced', gamma=0.003353947708867765)

# %% [markdown]
# - # Avaliação quantitativa do modelo no conjunto de teste

# %%
print("Predicting people's names on the test set")
t0 = time()
y_pred = clf.predict(X_test_pca)
print("done in %0.3fs" % (time() - t0))

print(classification_report(y_test, y_pred, target_names=target_names))
ConfusionMatrixDisplay.from_estimator(
    clf, X_test_pca, y_test, display_labels=target_names, xticks_rotation="vertical"
)
plt.tight_layout()
plt.show()
# Out:
# Predicting people's names on the test set
# done in 0.070s
#                    precision    recall  f1-score   support
#
#      Ariel Sharon       0.75      0.69      0.72        13
#      Colin Powell       0.76      0.88      0.82        60
#   Donald Rumsfeld       0.82      0.67      0.73        27
#     George W Bush       0.90      0.96      0.93       146
# Gerhard Schroeder       0.87      0.80      0.83        25
#       Hugo Chavez       0.80      0.53      0.64        15
#        Tony Blair       0.93      0.75      0.83        36
#
#          accuracy                           0.85       322
#         macro avg       0.83      0.75      0.79       322
#      weighted avg       0.86      0.85      0.85       322

# %% [markdown]
# - # Avaliação qualitativa das previsões usando matplotlib

# %%
def plot_gallery(images, titles, h, w, n_row=3, n_col=4):
    """Helper function to plot a gallery of portraits"""
    plt.figure(figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=0.01, right=0.99, top=0.90, hspace=0.35)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
        plt.title(titles[i], size=12)
        plt.xticks(())
        plt.yticks(())

# %%
def title(y_pred, y_test, target_names, i):
    pred_name = target_names[y_pred[i]].rsplit(" ", 1)[-1]
    true_name = target_names[y_test[i]].rsplit(" ", 1)[-1]
    return "predicted: %s\ntrue:      %s" % (pred_name, true_name)


prediction_titles = [
    title(y_pred, y_test, target_names, i) for i in range(y_pred.shape[0])
]

plot_gallery(X_test, prediction_titles, h, w)

# %%
eigenface_titles = ["eigenface %d" % i for i in range(eigenfaces.shape[0])]
plot_gallery(eigenfaces, eigenface_titles, h, w)

plt.show()
